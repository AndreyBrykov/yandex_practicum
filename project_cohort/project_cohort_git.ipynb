# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузите-данные-и-подготовьте-их-к-анализу" data-toc-modified-id="Загрузите-данные-и-подготовьте-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузите данные и подготовьте их к анализу</a></span><ul class="toc-item"><li><span><a href="#Первый-взгляд" data-toc-modified-id="Первый-взгляд-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Первый взгляд</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Проверка-на-дубликаты" data-toc-modified-id="Проверка-на-дубликаты-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка на дубликаты</a></span></li></ul></li><li><span><a href="#Задайте-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Задайте-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span></li><li><span><a href="#Оцените-окупаемость-рекламы" data-toc-modified-id="Оцените-окупаемость-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оцените окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Окупаемость-рекламы" data-toc-modified-id="Окупаемость-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Окупаемость рекламы</a></span></li><li><span><a href="#Конверсия-и-удержание" data-toc-modified-id="Конверсия-и-удержание-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Конверсия и удержание</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span><ul class="toc-item"><li><span><a href="#Наблюдения-по-исходным-данным" data-toc-modified-id="Наблюдения-по-исходным-данным-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Наблюдения по исходным данным</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></li></ul></div>

# %% [markdown]
# Мне, как маркетинговому аналитику развлекательного приложения Procrastinate Pro+, требуется разобраться в причинах убытков и помочь компании выйти в плюс. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
#
# **Описание данных**
# Предоставлены данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
#  - лог сервера с данными об их посещениях,
#  - выгрузка их покупок за этот период,
#  - рекламные расходы.
#
# Структура `visits_info_short.csv`:
#  * `User Id` — уникальный идентификатор пользователя,
#  * `Region` — страна пользователя,
#  * `Device` — тип устройства пользователя,
#  * `Channel` — идентификатор источника перехода,
#  * `Session Start` — дата и время начала сессии,
#  * `Session End` — дата и время окончания сессии.
#
# Структура `orders_info_short.csv`:
#  * `User Id` — уникальный идентификатор пользователя,
#  * `Event Dt` — дата и время покупки,
#  * `Revenue` — сумма заказа.
#
# Структура `costs_info_short.csv`:
#  * `dt` — дата проведения рекламной кампании,
#  * `Channel` — идентификатор рекламного источника,
#  * `costs` — расходы на эту кампанию.
#
# **План работы**
# Для выяснения причин убытков потребуется выяснить:
#  - откуда приходят пользователи и какими устройствами они пользуются,
#  - сколько стоит привлечение пользователей из различных рекламных каналов;
#  - сколько денег приносит каждый клиент,
#  - когда расходы на привлечение клиента окупаются,
#  - какие факторы мешают привлечению клиентов.

# %% [markdown]
# ### Загрузка данных и подготовка их к анализу

# %% [markdown]
# Загрузим данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучим данные и выполним предобработку. Есть ли в данных пропуски и дубликаты? Убедимся, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратим внимание на столбцы с датой и временем.

# %%
# подключаем библиотеки
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# загружаем данные из доступного источника
try:
    visits, orders, costs = (
        pd.read_csv('visits_info_short.csv'),  # журнал сессий
        pd.read_csv('orders_info_short.csv'),  # покупки
        pd.read_csv('costs_info_short.csv'),  # траты на рекламу
    )
except:
    print('Локально не получилось')
    visits, orders, costs = (
        pd.read_csv('https://code.s3.yandex.net/datasets/visits_info_short.csv'),  # журнал сессий
        pd.read_csv('https://code.s3.yandex.net/datasets/orders_info_short.csv'),  # покупки
        pd.read_csv('https://code.s3.yandex.net/datasets/costs_info_short.csv'),  # траты на рекламу
    )

# %% [markdown]
# #### Первый взгляд

# %% [markdown]
# Посмотрим содержимое журнала сессий.

# %%
# взглянем на первые 10 строк
visits.head(10)
# Out:
#         User Id         Region   Device         Channel        Session Start  \
# 0  981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac         organic  2019-05-01 03:33:35
# 5   90242400005  United States   iPhone  RocketSuperAds  2019-05-01 07:14:52
# 6   43958116050  United States  Android         organic  2019-05-01 09:03:21
# 7  185365244969  United States   iPhone         organic  2019-05-01 09:37:03
# 8  446013509831  United States   iPhone  RocketSuperAds  2019-05-01 10:26:00
# 9  100970711362  United States      Mac          TipTop  2019-05-01 04:39:53
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# ...

# %%
# приведем названия столбцов к "змеиному" стилю
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]
# взглянем на размер таблицы и содержимое
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Посмотрим содержимое данных о покупках.

# %%
# взглянем на первые 10 строк
orders.head(10)
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# 5  129100331057  2019-05-01 01:56:28     4.99
# 6  626807144131  2019-05-01 02:39:21     4.99
# 7  914062168985  2019-05-01 02:02:18     4.99
# 8  769669137453  2019-05-01 03:39:47     4.99
# 9  434198630691  2019-05-01 18:16:50     5.99

# %%
# приведем названия столбцов к "змеиному" стилю
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns]
# взглянем на размер таблицы и содержимое
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# Посмотрим содержимое данных о тратах на рекламу.

# %%
# взглянем на первые 10 строк
costs.head(10)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# 5  2019-05-06  FaceBoom  118.8
# 6  2019-05-07  FaceBoom  101.2
# 7  2019-05-08  FaceBoom  100.1
# 8  2019-05-09  FaceBoom   93.5
# 9  2019-05-10  FaceBoom  104.5

# %%
# приведем названия столбцов к "змеиному" стилю
costs.columns = [x.lower().replace(' ', '_') for x in costs.columns]
# взглянем на размер таблицы и содержимое
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Судя по информации о содержимом столбцов таблиц пропусков в них нет. Следует проверить на соответствие типов данных содержимому и проверить наличие дубликатов.

# %% [markdown]
# #### Изменение типов данных

# %%
# преобразуем тип данных в столбцах, которые содержат дату/время
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
# убедимся что типы данных в visits измненены
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
# убедимся что типы данных в  orders измненены
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
# убедимся что типы данных в costs изменены
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# #### Проверка на дубликаты

# %% [markdown]
# В журнале сессий присутствуют текстовые столбцы `region`, `device`, `channel`. Проверим, нет ли в них неявных дубликатов.

# %%
# смотрим набор уникальных значений в столбце 'region'
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
# смотрим набор уникальных значений в столбце 'device'
visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
# смотрим набор уникальных значений в столбце 'channel'
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Набор значений в столбцах `region`, `device`, `channel` не вызывает замечаний, содержимое соответствует ожиданиям. Теперь проверим, нет ли явных дубликатов в таблицах.

# %%
# считаем количество строк-дубликатов в visits
visits.duplicated().sum()
# Out:
# 0

# %%
# считаем количество строк-дубликатов в orders
orders.duplicated().sum()
# Out:
# 0

# %%
# считаем количество строк-дубликатов в costs
costs.duplicated().sum()
# Out:
# 0

# %%
# зададим функцию для первичного анализа датафрейма (для упрощения предыдущего кода, оставлен в сравнении)
def start_info(df):
    # имя таблицы
    name = [x for x in globals() if globals()[x] is df][0]
    print('\nПервые 5 строк таблицы {}:'.format(name))
    display(df.head())
    print('\nРаспределение численных значений в таблице {}:'.format(name))
    display(df.describe())
    # приведение к строчным буквам и замена пробелов в заголовках столбцов
    df.columns = [x.lower().replace(' ', '_') for x in df.columns]
    print('\nЗаголовки приведены к змеиному стилю.  \nИнформация о содержимом {}:'.format(name))
    display(df.info())
    # цикл по нечисловым столбцам для просмотра частоты значений в них
    for x in df.columns:
        if df[x].dtype == 'object':
            print('\nЧастота строк в столбце {}:'.format(x))
            print(df[x].value_counts().sort_values(ascending=False))
    print('\nКоличество явных дубликатов в таблице {}:'.format(name), df.duplicated().sum())    

# проведем начальный анализ таблицы visits с помощью функции start_info
start_info(visits)
# Out:
# Первые 5 строк таблицы visits:
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           session_end
# 0 2019-05-01 02:45:01
# 1 2019-05-01 04:47:35
# 2 2019-05-01 15:32:08
# 3 2019-05-01 00:54:25
# 4 2019-05-01 03:57:40
# Распределение численных значений в таблице visits:
#             user_id
# count  3.099010e+05
# mean   4.997664e+11
# std    2.887899e+11
# min    5.993260e+05
# 25%    2.493691e+11
# 50%    4.989906e+11
# 75%    7.495211e+11
# max    9.999996e+11
# Заголовки приведены к змеиному стилю.
# Информация о содержимом visits:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# Явных дубликатов не выявлено. Подготовку данных на этом можно завершить.

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# #### Функция для создания пользовательских профилей

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, events, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# #### Функция для расчёта удержания

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Функция для расчёта конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Функция для расчёта LTV и ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# #### Функция для сглаживания фрейма

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# #### Функция для визуализации удержания

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Функция для визуализации конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Функция для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders, [], costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определим минимальную и максимальную даты привлечения пользователей.

# %%
# доступный интервал привлечения пользователей
min_analysis_date = profiles['dt'].min()
observation_date = profiles['dt'].max()  # момент анализа
print('Минимальная дата привлечения пользователей:', min_analysis_date)
print('Максимальная дата привлечения пользователей:', observation_date)
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-27

# %% [markdown]
# Период в предоставленных данных соответствует анализируемому. Верхняя его граница будет выбрана с учетом горизонта анализа и реализована в соответствующих функциях.

# %% [markdown]
# Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.

# %%
# группируем профили по региону
region_user = profiles.groupby('region').agg({'user_id':'nunique'})
# группируем профили только платящих пользователей по региону
region_pay_user = profiles.query('payer == True').groupby('region').agg({'user_id':'nunique'})
# объединяем группировки в одну таблицу
region_table = region_user.reset_index().merge(region_pay_user.reset_index(), on='region', how='left')
region_table.columns = ['region','users','payers']
# вычислим долю платящих пользоваталей по странам
region_table['payers_share'] = round(region_table['payers'] / region_table['users'], 4)
display(
    pd.DataFrame(region_table.sort_values('payers_share', ascending = False)
                 .reset_index(drop=True)).style.format({'payers_share': '{:.2%}'}).background_gradient('coolwarm')
)

# визуализируем распределение пользователей по странам
# задаём размер сетки для графиков
plt.figure(figsize=(12, 7))
# круговая диаграмма всех пользователей по странам
ax1 = plt.subplot(1, 2, 1)
(
    
    region_user.sort_values(by='user_id', ascending=False).
    plot(y='user_id', kind='pie', autopct='%1.1f%%',
        shadow=True, startangle=0, ax=ax1)
)
plt.xlabel('Пользователи')
plt.title('Количество пользователей по странам')
# круговая диаграмма платящих пользователей по странам
ax2 = plt.subplot(1, 2, 2)
(
    
    region_pay_user.sort_values(by='user_id', ascending=False).
    plot(y='user_id', kind='pie', autopct='%1.1f%%',
        shadow=True, startangle=0, ax=ax2)
)
plt.xlabel('Платящие пользователи')
plt.title('Количество платящих пользователей по странам')

plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_8b6a3_row0_col1, #T_8b6a3_row0_col2, #T_8b6a3_row0_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8b6a3_row1_col1, #T_8b6a3_row1_col2, #T_8b6a3_row3_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8b6a3_row1_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_8b6a3_row2_col1, #T_8b6a3_row3_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_8b6a3_row2_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_8b6a3_row2_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_8b6a3_row3_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8b6a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b6a3_level0_col0" class="col_heading level0 col0" >region</th>
#       <th id="T_8b6a3_level0_col1" class="col_heading level0 col1" >users</th>
# ...

# %% [markdown]
# Подавляющее число пользователей приложения - пользоватлели из США (почти 67%). Пользователи из Германии, Франции и Великобритании занимают от 10% до 12% от общего числа пользователей.
#
# Среди платящих пользователей клиенты из США имеют еще больший процент - это объясняется тем, что в этой стране самая высокая доля платящих пользователей - почти 7%.

# %% [markdown]
# Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.

# %%
# группируем профили по устройствам
device_user = profiles.groupby('device').agg({'user_id':'nunique'})
# группируем профили только платящих пользователей по устройству
device_pay_user = profiles.query('payer == True').groupby('device').agg({'user_id':'nunique'})
# объединяем группировки в одну таблицу
device_table = device_user.reset_index().merge(device_pay_user.reset_index(), on='device', how='left')
device_table.columns = ['device','users','payers']
# вычислим долю платящих пользоваталей по устройствам
device_table['payers_share'] = round(device_table['payers'] / device_table['users'], 4)
display(
    pd.DataFrame(device_table.sort_values('payers_share', ascending = False).
                 reset_index(drop=True)).style.format({'payers_share': '{:.2%}'}).background_gradient('coolwarm')
)


# визуализируем распределение пользователей по устройствам
# задаём размер сетки для графиков
plt.figure(figsize=(12, 7))
# круговая диаграмма всех пользователей по странам
ax1 = plt.subplot(1, 2, 1)
(
    
    device_user.sort_values(by='user_id', ascending=False).
    plot(y='user_id', kind='pie', autopct='%1.1f%%',
        shadow=True, startangle=0, ax=ax1)
)
plt.xlabel('Пользователи')
plt.title('Количество пользователей по устройствам')
# круговая диаграмма платящих пользователей по странам
ax2 = plt.subplot(1, 2, 2)
(
    
    device_pay_user.sort_values(by='user_id', ascending=False).
    plot(y='user_id', kind='pie', autopct='%1.1f%%',
        shadow=True, startangle=0, ax=ax2)
)
plt.xlabel('Платящие пользователи')
plt.title('Количество платящих пользователей по устройствам')

plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_31f0a_row0_col1, #T_31f0a_row3_col2, #T_31f0a_row3_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_31f0a_row0_col2, #T_31f0a_row2_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_31f0a_row0_col3, #T_31f0a_row1_col1, #T_31f0a_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_31f0a_row1_col3 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_31f0a_row2_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_31f0a_row2_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_31f0a_row3_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_31f0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31f0a_level0_col0" class="col_heading level0 col0" >device</th>
#       <th id="T_31f0a_level0_col1" class="col_heading level0 col1" >users</th>
# ...

# %% [markdown]
# Чаще других пользователи используют приложение на iPhone. Следом идут пользователи Android. Приложение на PC и Mac имеют примерно одинаковое число пользоваталей.
#
# Доля платящих пользователей распределена иначе, выше всего она среди пользователей на Mac, следом идут пользователи на iPhone. Доля платящих пользователей среди Android и PC на 3 и 4 месте соответственно.

# %% [markdown]
# Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.

# %%
# группируем профили по источникам
channel_user = profiles.groupby('channel').agg({'user_id':'nunique'})
# группируем профили только платящих пользователей по источникам
channel_pay_user = profiles.query('payer == True').groupby('channel').agg({'user_id':'nunique'})
# объединяем группировки в одну таблицу
channel_table = channel_user.reset_index().merge(channel_pay_user.reset_index(), on='channel', how='left')
channel_table.columns = ['channel','users','payers']
# вычислим долю платящих пользоваталей по источникам
channel_table['payers_share'] = round(channel_table['payers'] / channel_table['users'], 4)
(
    pd.DataFrame(channel_table.sort_values('payers_share', ascending = False)
                 .reset_index(drop=True))
    .style.format({'payers_share': '{:.2%}'}).background_gradient('coolwarm')
)
# Out:
# <style type="text/css">
# #T_4827d_row0_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_4827d_row0_col2, #T_4827d_row0_col3, #T_4827d_row10_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4827d_row1_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_4827d_row1_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_4827d_row1_col3 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_4827d_row2_col1, #T_4827d_row6_col2, #T_4827d_row7_col2, #T_4827d_row10_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4827d_row2_col2, #T_4827d_row9_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4827d_row2_col3 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_4827d_row3_col1 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_4827d_row3_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_4827d_row3_col3 {
#   background-color: #f59c7d;
# ...

# %% [markdown]
# Наибольшее число клиентов приложения это самостоятельно нашедшие приложение или скачавшие его по прямой ссылке. Из рекламных источников выделяется FaceBoom - этот канал помог установить приложение 29144 пользоваталям. Следом идет TipTop, остальные имеют гораздо меньшие результаты.
#
# Органические пользователи закономерно имеют наименьшую долю платящих. У самого крупного канала по привлечению новых пользователей - FaceBoom и самая большая доля платящих пользователей. А вот TipTop имеет не такой высокий процент готовых платить, AdNonSense и lambdaMediaAds привлекают более "качественных" пользователей по сравнению с ним.

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %%
# посчитаем общие расходы на маркетинг
print('Расходы на маркетинг в наблюдаемый период:', round(costs['costs'].sum()))
# Out:
# Расходы на маркетинг в наблюдаемый период: 105497

# %%
# сгруппируем расходы на рекламу по каналам привлечения и вычислим сумму расходов
display(costs.groupby('channel').agg({'costs':'sum'}).sort_values('costs', ascending = False))
# визуализируем распределение расходов по каналам
(
    costs.groupby('channel').agg({'costs':'sum'})
    .sort_values('costs')
    .plot(grid = True, kind='bar', rot=45, figsize=(8,5), color='g', alpha=0.6, )
)
plt.xlabel('Канал привлечения')
plt.title('Расходы на рекламу по каналам привлечения')
plt.show()
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# Общие расходы на маркетинг в наблюдаемый период составили 105497.
#
# В лидерах по расходам два рекламных источника TipTop и FaceBoom, со значениями расходов 54751 и 32445 соответственно. На третьем месте по расходам - WahooNetBanner, он значительно отстает со значением расходов - 5151. На остальные источники затраты были меньше.

# %%
# сделаем столбец у усеченной до недели датой рекламного расхода
costs['week'] = costs['dt'].astype('datetime64[W]')
# построим графики динамики расходов по каналам
(
    costs.pivot_table(index='week', columns='channel', values='costs', aggfunc='sum')
    .plot(grid = True, figsize = (12, 7))
)
plt.xlabel('Неделя расходов')
plt.title('Динамика изменения рекламных расходов по каждому источнику')
plt.show()

# %%
# построим графики динамики расходов по срезу каналов без TipTop и FaceBoom
(
    costs.query('channel not in ("TipTop","FaceBoom")').pivot_table(index='week', columns='channel', values='costs', aggfunc='sum')
    .plot(grid = True, figsize = (12, 7))
)
plt.xlabel('Неделя расходов')
plt.title('Динамика изменения рекламных расходов по источникам без TipTop и FaceBoom')
plt.show()

# %% [markdown]
# На графике динамики изменения расходов на рекламу можно наблюдать, что расходы по двум источникам привлечения - TipTop и FaceBoom росли практически во всем периоде и существенно превосходили остальные. Не удивительно, что из этих источников пришло большинство неорганических пользователей. Только вот хоть расходы на канал TipTop и превышали FaceBoom, последний привлек пользователей больше, к тому же среди них выше доля платящих. В сентябре расходы на рекламу по этим двум каналам достигли максимума. Другие платные источники привлечения пользователей не показывали значительной динамики изменений и расходы на них были примерно на одном уровне.

# %%
# сгруппируем пользователей по каналам привелечения и посчитаем средние расходы на привлечение одного пользователя (CAC)
(
    profiles.groupby('channel')
    .agg(mean_cac=('acquisition_cost','mean'))
    .sort_values('mean_cac', ascending = False)
)
# Out:
#                     mean_cac
# channel
# TipTop              2.799003
# FaceBoom            1.113286
# AdNonSense          1.008054
# lambdaMediaAds      0.724802
# WahooNetBanner      0.602245
# RocketSuperAds      0.412095
# OppleCreativeMedia  0.250000
# YRabbit             0.218975
# MediaTornado        0.218717
# LeapBob             0.210172
# organic             0.000000

# %% [markdown]
# Рекламный исчточник TipTop значительно оторвался от других по средней стоимости привлечения одного пользователя. Привлечение пользователя в TipTop в среднем стоило в 2.5 раза больше чем в FaceBoom. На третьем месте по стоимости привлечения AdNonSense, но он хотя бы приводит пользоваталей с высокой долей платящих.

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# #### Окупаемость рекламы

# %%
# зададим момент анализа
observation_date = datetime(2019, 11, 1).date()
# зададим горизонт анализа
horizon_days = 14

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, )

# строим графики, для очистки от шума зададим скользящее среднее равным 7
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, 7)

# %% [markdown]
# Проанализируем графики LTV, ROI и динамики LTV, CAC и ROI.
#
# Отметим что кривая LTV ожидаемо растет и не снижается на всем горизонте лайфтаймов на протяжении 14 дней после привлечения. На графике динамики LTV можно отметить, что имеются ежемесячные колебания денежных поступлений от 14-ти дневных пользоваталей в зависимости от даты их привлечения. В июне стоимость привлечения заметно возросла и продолжила постепенно расти до октября 2019 г., увеличившись за период почти в 2 раза.
#
# Заложенная в бизнес-плане окупаемость, не позднее чем через две недели после привлечения пользователя, не выполняется - на 14-й день ROI достигает лишь значения 0.8. С июля 2019 года ROI пользователя на 14-й день опустился ниже 1, расходы на привлечение перестали окупаться.

# %% [markdown]
# Изменим горизонт анализа и посмотрим когда окупаются вложения в рекламу и происходит ли это.

# %%
# изменим горизонт анализа на 1 месяц
horizon_days = 30

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, )

# строим графики, для очистки от шума зададим скользящее среднее равным 7
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, 7)

# %% [markdown]
# Расходы на привлечение неорганических пользователей окупаются на 23-й день "жизни", что не соответствет бизнес-плану.

# %% [markdown]
# #### Конверсия и удержание

# %%
# вернем исходный горизонт анализа
horizon_days = 14

# посмотрим конверсию
dimensions = []

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# дополнительно посмотрим конверсию в разрезе регионов
dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# На 8-й день и позднее после регистрации от пользователей уже не стоит ожидать покупок, конверсия выходит на горизонтальный участок.
#
# Конверсия в мае и июне везде, кроме США, резко упала, а затем выросла. В дальнейшем конверсия продолжила ежемесячные колебания примерно на одном уровне. Конверсия в США выше других регионов. Штаты же внесли основной вклад в динамику конверсии пользователей на 14-й день.

# %%
# посмотрим удержание

retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('channel != "organic"'), visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# На первый день после привлечения остается менее 40% платящих пользователей. Их число постепенно снижается и к 14-му дню остается меньше 10% платящих пользователей. Хуже других удерживаются пользователи из США.
#
# Неплатящие пользователи быстро уходят, они почти не "доживают" до 6-го дня пользования приложением.
#
# Динамика удержания платящих пользователей на 14-й день в целом показывает одинаковые колебания на всем наблюдаемом периоде привлечения.
#
# Динамика удержания неплатящих пользователей на 14-й день неизменна, к 14-му дню их практически не остается независимо от даты привлечения.

# %%
# посмотрим удержание в США по каналам
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('channel != "organic" and region == "United States"'), visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание канала FaceBoom существенно ниже других в США, при том что это крупнейшие источники пользователей.

# %% [markdown]
# #### Окупаемость рекламы с разбивкой по устройствам

# %%
# зададим дополнительный признак для когорт
dimensions = ['device']

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# LTV схоже растет на протяжении 14 дней после привлечения для пользователей на всех устройствах.
#
# Динамика LTV на 14-й день в зависимости от устройств пользователей не имеет особенностей, зависимости от устройства пользователя не прослеживается.
#
# Динамика стоимости привлечения похожа, но отличается уровнем значений - стоимость привлечения на Mac и iPhone выросла в июне выше других устройств и продолжила рост динамичней других. Привлекать пользователей на PC стоит дешевле всего, в июне рост оказался не таким большим как на других устройствах, но тренд на повышение также присутствует.
#
# Привлечение клиентов использующих PC окупается за обозначенные в бизнес-плане 14 дней - ROI превышает значение 1 на 12-й день. Поступление денежных средств от пользователей приложения на Android, Mac и iPhone не покрывает расходы на их привлечение за две недели "жизни" клиента.
#
# С июля ROI пользователей на 14 день после привлечения почти у всех устройств, кроме PC, ниже окупаемости. Только пользователи, использующие PC, еще окупались, но к октябрю и их ROI стал снижаться ниже 1.

# %%
# зададим дополнительный признак для когорт
dimensions = ['region']

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# В период 14 дней после привлечения LTV схоже растет у пользователей всех стран, но уровень LTV в США выше - пользователи из этой страны приносят больше денег.
#
# В зависимости от страны пользователя динамика LTV на 14-й день колебалась на различных уровнях. Поступления денег на 14-й день были максимальными у пользователей, привлеченных в июне из США, а также привлеченных в некоторые дни июля и августа из Соединенного королевства.
#
# Стоимость привлечения пользователей из США резко выросла в июне и продолжила рост до октября. В остальных странах стоимость привлечения наоборот снизилась в июне после чего дальнейшие колебания незначительны.
#
# Рост стоимости привлечения в штатах значительно повлиял на окупаемость привлечения в течении 14 дней - ROI клиентов из США на превышает значение 1, эти клиенты приносят убытки. Пользователи других стран к 14-му дню денежными поступлениями превышают расходы на их привелечение в 1.5 раза.
#
# Динамика ROI пользователей на 14-й день говорит о том, что привлеченные из США пользователи после июня перестали окупать затраты на их привлечение. Расходы на привлечение пользователей из других стран почти всегда окупались за 14 дней. Только клиенты привлеченные в некоторые дни мая, сентября и октября  из Франции, Германии и Соединенного королевства на 14-й день не окупили рекламные расходы.

# %%
# зададим дополнительный признак для когорт
dimensions = ['channel']

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# При таком количестве визуальной информации сложно проанализировать данные. Отметим лишь некоторые особенности, а в дальнейшем рассмотрим подробней некоторые каналы привлечения. Стоит подробней изучить окупаемость каналов TipTop, FaceBoom, lambdaMediaAds, YRabbit, AdNonSense. Сделаем срез и посмотрим на них внимательней.

# %%
# зададим дополнительный признак для когорт
dimensions = ['channel']

# считаем LTV и ROI по срезу
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel in ("TipTop","FaceBoom","AdNonSense","lambdaMediaAds","YRabbit")'), 
    orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# В течении первых 14 дней после привлечения LTV пользователей, пришедших через FaceBoom, AdNonSense и YRabbit, практически не растет - поступления от клиентов прекращаются уже на второй день. Привлеченные с помощью TipTop и lambdaMediaAds пользователи имеют лучшие показатели по LTV.
#
# Привлеченные lambdaMediaAds пользователи в первой половине июня показали выдающиеся значения LTV на 14-й день. В остальном динамика на 14-й день соответствует уровням LTV на первом графике, лидеры и аутсайдеры на всем наблюдаемом отрезке те же.
#
# **Динамика стоимости привлечения пользователей каналом TipTop требует повышенного внимания**. Стоимость привлечения в этом рекламном канале росла ежемесячно и к октябрю превысила стоимость любого источника более чем в 3.5 раза.
#
# Лидеры рентабельности за 2 недели "жизни" - пользователи, привлеченные lambdaMediaAds и YRabbit, они окупают расходы на привлечение на второй день. TipTop, FaceBoom и AdNonSense не окупают расходов на привлечение клиентов, за две недели "жизни" эти пользователи не приносят нужной суммы денег.
#
# Привлеченные YRabbit в июле пользователи продемонстрировали отличные показатели окупаемости расходов на рекламу за 2 недели "жизни", но к октябрю динамика ROI пользователей пришедших из этого канала ухудшилась. В наблюдаемом периоде привлечение клиентов приложения через TipTop и FaceBoom не окупалось за 14 дней ни разу.

# %% [markdown]
# Дополнительно выясним из каких стран привлекал клиентов TipTop.

# %%
# зададим дополнительный признак для когорт
dimensions = ['region']

# считаем LTV и ROI по срезу - только TipTop
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel == "TipTop"'), 
    orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# TipTop привлекал клиентов только из штатов, вот почему динамика стоимости привлечения в США покзала такой рост. Согласно динамики ROI в мае этот источник приводил клиентов, которые окупали расходы на рекламу за 14 дней. Но после роста стоимости привлечения в следующие месяцы никакие высокие значения LTV пользователей на 14-й день не превышали расходов на рекламу.

# %% [markdown]
# Также проверим, на всех ли устройствах стоимость привлечения TipTop росла одинаково.

# %%
# зададим дополнительный признак для когорт
dimensions = ['device']

# считаем LTV и ROI по срезу
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel == "TipTop"'), 
    orders, observation_date, horizon_days, dimensions = dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Клиенты на всех устройствах, пришедшие через TipTop, имеют идентичную динамику стоимости привлечения.

# %% [markdown]
# Оценим влияние канала TipTop на показатели - посмотрим какое место он занимает в привлечении  пользователей.

# %%
# считаем количество пользователей по всем рекламным каналам в разрезе стран
pd.DataFrame(
    profiles.query('channel != "organic"').pivot_table(index='channel', 
                                                   columns='region', 
                                                   values='user_id', 
                                                   aggfunc='nunique').fillna(0)
    ).style.format('{:.0f}').background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_a2e33_row0_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a2e33_row0_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_a2e33_row0_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_a2e33_row0_col3, #T_a2e33_row1_col0, #T_a2e33_row1_col1, #T_a2e33_row1_col2, #T_a2e33_row2_col3, #T_a2e33_row3_col0, #T_a2e33_row3_col1, #T_a2e33_row3_col2, #T_a2e33_row4_col3, #T_a2e33_row5_col0, #T_a2e33_row5_col1, #T_a2e33_row5_col2, #T_a2e33_row6_col0, #T_a2e33_row6_col1, #T_a2e33_row6_col2, #T_a2e33_row7_col3, #T_a2e33_row8_col0, #T_a2e33_row8_col1, #T_a2e33_row8_col2, #T_a2e33_row9_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a2e33_row1_col3, #T_a2e33_row2_col0, #T_a2e33_row2_col2, #T_a2e33_row4_col0, #T_a2e33_row4_col2, #T_a2e33_row7_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a2e33_row2_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_a2e33_row3_col3 {
# ...

# %% [markdown]
# **Выводы об окупаемости рекламы:**
#
# Реклама на привлечение пользователей за первые 14 дней "жизни" клиента не окупается, лишь порядка 80% расходов поркрывается поступлениями от пользователей.
#
# Стоимость привлечения пользователей из США негативно сказывается на окупаемости - за 14 дней "жизни" клиента из штатов поступление денег от него не дотягиевает до расходов на его привлечение.
#
# Главный рекламным каналом, тянущим окупаемость вниз, является TipTop. Затраты на клиента, пришедшего через этот канал никогда не окупаются. TipTop работает только по привлечению клиентов из США, поэтому эта страна имеет худшие показатели окупаемости. Поскольку этот рекламный канал является вторым по числу привлеченных клиентов, то он оказывает существенное влияние на показатели окупаемости рекламы приложения в целом.
#
# Cроки рекламных кампаний обычно подчиняются общепринятым временным периодам, чаще всего месяцам или кварталам. Так компаниям удобнее соотносить бюджет на рекламу с финансовым планом и периодами отчётности, поэтому большинство рекламных кампаний запускается в начале месяца, а заканчивается в конце. Похоже это прослеживается на графике изменения стоимости привлечения в источнике TipTop. Почему каждая рекламная кампания с новым месяцем так дорожает - задача для отдела маркетинга.
#
# Кроме TipTop, FaceBoom и AdNonSense не окупают расходов на привлечение клиентов, за 14 дней после привлечения эти пользователи не приносят нужной суммы денег.
#
# Требуется принятие решения по работе с TipTop, этот канал слишком дорог.

# %% [markdown]
# ### Выводы
#
# Согласно поставленной задачи предстояло проанализировать вложения в рекламу развлекательного приложения Procrastinate Pro+ и оценить их окупаемость за последние несколько месяцев, разобраться в причинах убытков и дать рекомендации компании для выхода в плюс.
#
# #### Наблюдения по исходным данным
#
# 1. Данные содержат информацию о пользователях, привлечённых с 1 мая по 27 октября 2019 года - это данные о посещениях и покупках, а также рекламные расходы компании.
# 2. По результатам изучения исходных данных была определена их достаточность для анализа в рамках поставленной задачи.
# 3. Наибольшее число клиентов приложения это органические пользователи. Из рекламных источников лидеры по привлечению - FaceBoom и TipTop, остальные имеют гораздо меньшие результаты привлечения.
# 4. Органические пользователи закономерно имеют наименьшую долю платящих. У самого крупного канала по привлечению новых пользователей - FaceBoom и самая большая доля платящих пользователей. А вот TipTop имеет не такой высокий процент готовых платить, AdNonSense и lambdaMediaAds привлекают более "качественных" пользователей по сравнению с ним.
# 5. Чаще других пользователи используют приложение на iPhone - 36%. Приложением на Android, PC и Mac пользуются примерно одинаковое число клиентов - около 20%.
# 6. Подавляющее число пользователей приложения - пользоватлели из США (почти 67%), в этой же стране самая высокая доля платящих пользователей - почти 7%.
# 7. Доля платящих пользователей выше других среди пользователей на Mac, следом идут пользователи на iPhone. Доля платящих пользователей среди Android и PC на 3 и 4 месте соответственно.
# 8. Лидеры по расходам на рекламу - источники TipTop и FaceBoom, со значениями расходов 54751 и 32445 соответственно. До октября 2019 года расходы на рекламу в этих каналах росли. На остальные каналы рекламы расходы были значительно меньше.
# 9. Самая высокая стоимость привлечения у TipTop	- 2.8, за ним следуют FaceBoom и AdNonSense со стоимостью за пользователя 1.1 и 1.0 соответственно. Дешевле всех обходится привлеченние в LeapBob - 0.2.
# 10. Привлечение из платных источников не окупается за 2 недели "жизни" пользователя.
# 11. Динамика привлечения пользователей каналом TipTop требует повышенного внимания. Стоимость привлечения в этом рекламном канале росла ежемесячно и к октябрю превысила стоимость любого источника более чем в 3.5 раза. Все пользователи, привлеченные этим каналом, из США.
# 12. Удержание пользователей из FaceBoom в США ниже других каналов.
#
#
# #### Общий вывод
#
# Пробемы с окупаемостью во многом обусловлены ростом стоимости привлечения в рекламном канале TipTop, через который приходит значительное число пользователей. Кроме того, FaceBoom и AdNonSense не окупают расходов на привлечение клиентов.
#
# Отделу маркетинга рекомендуется выяснить причины ежемесячного повышения стоимости привлечения у платного источника пользователей TipTop и пересмотреть раходы на этот канал.
# Для повышения рентабельности пользователей, пришедших через FaceBoom и AdNonSense, отделу маркетинга рекомендуется принять меры по повышению маркетинговой конверсии этих каналов.
